# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt

def decay(x, factor):
    return x*factor

x = []
y = []
e = 1
for i in range(100):
    x.append(i)
    y.append(e)
    e = decay(e, 0.98)     

fig, ax = plt.subplots()

plt.plot(x,y)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
