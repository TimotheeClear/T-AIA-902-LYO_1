# %%
import sys
sys.path.append('../.')
from markov.ParamTuner import TuningExperiment
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2024-06-28 15:51:24.663164: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-28 15:51:25.524171: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
experiment = TuningExperiment(
    start_episodes=150, 
    end_episodes=2001, 
    num_tuners=50, 
    n_calls=75,
    nb_agents=10,
    random_state=0
    )
experiment.run_tuners()
# Out:
# Parameter tuning n° 201/[201, 401, 601, 801, 1001]
# Iteration No: 1 started. Evaluating function at random point.
# Params tested:
# {'alpha': 0.709070890683614, 'epsilon': 0.4911124395973136, 'gamma': 0.9954235789779059}
# Training agent agent_0:
# 	Episode n°50 total reward: -63591
# 	Episode n°100 total reward: -57230
# 	Episode n°150 total reward: -56956
# 	Episode n°200 total reward: -41083
# Training agent agent_1:
# 	Episode n°50 total reward: -61800
# 	Episode n°100 total reward: -56844
# 	Episode n°150 total reward: -51121
# 	Episode n°200 total reward: -36689
# Training agent agent_2:
# 	Episode n°50 total reward: -66764
# 	Episode n°100 total reward: -56613
# 	Episode n°150 total reward: -49037
# 	Episode n°200 total reward: -35184
# Training agent agent_3:
# 	Episode n°50 total reward: -102903
# 	Episode n°100 total reward: -58299
# 	Episode n°150 total reward: -46924
# 	Episode n°200 total reward: -40312
# Median adjusted score: 163522.0
#
# ...

# %%
results = experiment.get_results()
print(results)
# Out:
# {201: {'alpha': 1.0, 'epsilon': 0.3169456151492154, 'gamma': 0.3616447265242399}, 401: {'alpha': 0.7652528118489018, 'epsilon': 0.8130462295343808, 'gamma': 1.0}, 601: {'alpha': 0.7823613429501795, 'epsilon': 0.9207737094164132, 'gamma': 0.917057304428002}, 801: {'alpha': 0.6935606900826445, 'epsilon': 1.0, 'gamma': 1.0}, 1001: {'alpha': 0.5532798908810764, 'epsilon': 1.0, 'gamma': 0.936559642260448}}

# %%
experiment.plot_individual_parameters()

# %%
experiment.plot_all_parameters()
